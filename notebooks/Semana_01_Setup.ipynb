# %%
# Semana 1 – Setup del proyecto BTC
# Objetivo: Obtener datos OHLCV de BTC y guardarlos en formato Parquet

# Instalar librerías necesarias (solo si hace falta)
# !pip install yfinance pyarrow ccxt

# %%
# Conectar con Google Drive para guardar datos
from google.colab import drive
drive.mount('/content/drive')

# Crear carpetas del proyecto en Google Drive
import os

base_dir = "/content/drive/MyDrive/btc_prediction_project"
data_dir = os.path.join(base_dir, "data")
os.makedirs(data_dir, exist_ok=True)

# Descargar datos de BTC con yfinance
import yfinance as yf
import pandas as pd

btc = yf.download("BTC-USD", start="2015-01-01", interval="1d")
btc.to_parquet(f"{data_dir}/btc_yfinance.parquet")

# Mostrar últimas filas como validación
btc.tail()
# Out:
# /tmp/ipython-input-19-936837085.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download("BTC-USD", start="2015-01-01", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-06-17  104601.117188  107750.195312  103396.531250  106794.117188
# 2025-06-18  104883.328125  105581.851562  103602.265625  104602.070312
# 2025-06-19  104684.289062  105250.890625  103940.773438  104886.773438
# 2025-06-20  103309.601562  106539.382812  102372.210938  104681.031250
# 2025-06-21  103575.585938  104008.515625  103177.843750  103309.835938
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2025-06-17  55964092176
# ...

# %%
data_dir = "/content/drive/MyDrive/btc_prediction_project/data"
print("Archivos en data/:", os.listdir(data_dir))
# Out:
# Archivos en data/: ['btc_yfinance.parquet']

# %%
# !git config --global user.email "isarelamatgil@gmail.com"
# !git config --global user.name "isarelamat"

# %%
# !git clone https://github.com/tu_usuario/tu_repositorio.git

# %%
# Nueva celda para porbar sistema de guardado
